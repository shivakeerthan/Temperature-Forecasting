# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (435742, 8)

# %%
df.head()
# Out:
#             state   location                                type  so2   no2  \
# 0  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  4.8  17.4
# 1  Andhra Pradesh  Hyderabad                     Industrial Area  3.1   7.0
# 2  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.2  28.5
# 3  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.3  14.7
# 4  Andhra Pradesh  Hyderabad                     Industrial Area  4.7   7.5
#
#    rspm  spm      date
# 0   NaN  NaN  2/1/1990
# 1   NaN  NaN  2/1/1990
# 2   NaN  NaN  2/1/1990
# 3   NaN  NaN  3/1/1990
# 4   NaN  NaN  3/1/1990

# %%
df.columns
# Out:
# Index(['state', 'location', 'type', 'so2', 'no2', 'rspm', 'spm', 'date'], dtype='object')

# %%
df.shape
# Out:
# (435742, 8)

# %%
df['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli',
#        'Daman & Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Uttar Pradesh',
#        'Uttarakhand', 'Uttaranchal', 'West Bengal',
#        'andaman-and-nicobar-islands', 'Lakshadweep', 'Tripura'],
#       dtype=object)

# %%
df['state'].value_counts()
# Out:
# Maharashtra                    60384
# Uttar Pradesh                  42816
# Andhra Pradesh                 26368
# Punjab                         25634
# Rajasthan                      25589
# Kerala                         24728
# Himachal Pradesh               22896
# West Bengal                    22463
# Gujarat                        21279
# Tamil Nadu                     20597
# Madhya Pradesh                 19920
# Assam                          19361
# Odisha                         19279
# Karnataka                      17119
# Delhi                           8551
# Chandigarh                      8520
# Chhattisgarh                    7831
# Goa                             6206
# Jharkhand                       5968
# Mizoram                         5338
# Telangana                       3978
# Meghalaya                       3853
# Puducherry                      3785
# Haryana                         3420
# Nagaland                        2463
# ...

# %%
df_r=df.dropna(axis=0)

# %%
df_r.shape
# Out:
# (141732, 8)

# %%
df_r['state'].value_counts()
# Out:
# Maharashtra             18085
# Uttar Pradesh           16762
# Rajasthan               13229
# Gujarat                 11837
# West Bengal             10977
# Andhra Pradesh          10630
# Madhya Pradesh           8841
# Tamil Nadu               7445
# Odisha                   7003
# Kerala                   6248
# Karnataka                5608
# Assam                    5535
# Chhattisgarh             3360
# Delhi                    3181
# Jharkhand                2606
# Goa                      2157
# Himachal Pradesh         1632
# Puducherry               1229
# Haryana                  1170
# Chandigarh               1110
# Bihar                     801
# Mizoram                   384
# Nagaland                  380
# Dadra & Nagar Haveli      301
# Daman & Diu               299
# Uttaranchal               248
# Punjab                    248
# Meghalaya                 223
# Jammu & Kashmir            94
# Uttarakhand                83
# Manipur                    25
# ...

# %%
dates=df_r['date'].values
dates
for i in dates:
    print(type(i))
    break
len(dates)
# Out:
# <class 'str'>
# 141732

# %%
import datetime
date_obj=datetime.datetime.strptime(dates[0],'%d/%m/%Y')

# %%
date_obj
# Out:
# datetime.datetime(2004, 1, 2, 0, 0)

# %%
month=date_obj.strftime("%b")

# %%
month
# Out:
# 'Jan'

# %% [markdown]
# taking all the dates and creating a new list extracting months..and join to the df

# %%
months=[]
years=[]

# %%
for i in dates:
    date=datetime.datetime.strptime(i,"%m/%d/%Y")
    months.append(date.strftime("%b"))
    years.append(date.strftime("%Y"))

# %%
months
# Out:
# ['Feb',
#  'May',
#  'Sep',
#  'Dec',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Mar',
#  'Jun',
#  'Sep',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'May',
#  'Sep',
#  'Nov',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Jun',
#  'Jul',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Jul',
#  'Oct',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Feb',
#  'May',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Feb',
#  'Jun',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jun',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Jan',
#  'Apr',
#  'Aug',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Jan',
#  'May',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Mar',
#  'Jun',
#  'Aug',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Feb',
#  'May',
# ...

# %%
# df_r['month']=months
len(months)
# Out:
# 141732

# %%
df_r['month']=months
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_r.head()
# Out:
#                state   location             type   so2    no2   rspm    spm  \
# 1036  Andhra Pradesh  Hyderabad  Industrial Area  12.9   55.8  143.7  370.7
# 1037  Andhra Pradesh  Hyderabad  Industrial Area  10.4   48.9  124.7  285.7
# 1038  Andhra Pradesh  Hyderabad  Industrial Area   7.6   50.1   88.0  221.3
# 1039  Andhra Pradesh  Hyderabad  Industrial Area   7.3   48.5   82.7  186.7
# 1040  Andhra Pradesh  Hyderabad  Industrial Area   6.8  110.3  122.3  270.7
#
#            date month
# 1036   2/1/2004   Feb
# 1037   5/1/2004   May
# 1038   9/1/2004   Sep
# 1039  12/1/2004   Dec
# 1040  1/16/2004   Jan

# %%
len(years)
# Out:
# 141732

# %%
df_r['year']=years
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_r.head()
# Out:
#                state   location             type   so2    no2   rspm    spm  \
# 1036  Andhra Pradesh  Hyderabad  Industrial Area  12.9   55.8  143.7  370.7
# 1037  Andhra Pradesh  Hyderabad  Industrial Area  10.4   48.9  124.7  285.7
# 1038  Andhra Pradesh  Hyderabad  Industrial Area   7.6   50.1   88.0  221.3
# 1039  Andhra Pradesh  Hyderabad  Industrial Area   7.3   48.5   82.7  186.7
# 1040  Andhra Pradesh  Hyderabad  Industrial Area   6.8  110.3  122.3  270.7
#
#            date month  year
# 1036   2/1/2004   Feb  2004
# 1037   5/1/2004   May  2004
# 1038   9/1/2004   Sep  2004
# 1039  12/1/2004   Dec  2004
# 1040  1/16/2004   Jan  2004

# %%
df_refined=df_r.drop(columns=['location','type','date'])

# %%
df_refined
# Out:
#                  state    so2     no2    rspm     spm month  year
# 1036    Andhra Pradesh  12.90   55.80  143.70  370.70   Feb  2004
# 1037    Andhra Pradesh  10.40   48.90  124.70  285.70   May  2004
# 1038    Andhra Pradesh   7.60   50.10   88.00  221.30   Sep  2004
# 1039    Andhra Pradesh   7.30   48.50   82.70  186.70   Dec  2004
# 1040    Andhra Pradesh   6.80  110.30  122.30  270.70   Jan  2004
# 1041    Andhra Pradesh   6.90  134.10  101.70  235.00   Jan  2004
# 1042    Andhra Pradesh   6.20   41.60   84.70  219.30   Jan  2004
# 1043    Andhra Pradesh   6.30   45.70   93.70  222.30   Jan  2004
# 1044    Andhra Pradesh   6.10   79.50   55.70  182.30   Jan  2004
# 1045    Andhra Pradesh   5.20   41.60   60.30  157.70   Mar  2004
# 1046    Andhra Pradesh   5.10   86.20  126.70  317.00   Jun  2004
# 1047    Andhra Pradesh   5.10   81.30   70.30  179.70   Sep  2004
# 1048    Andhra Pradesh   5.00   80.10  144.70  305.30   Feb  2004
# ...

# %%
df_grouped=df_refined.groupby(['state','year','month']).mean()

# %%
df_grouped.head()
# Out:
#                                 so2        no2        rspm         spm
# state          year month
# Andhra Pradesh 2004 Apr    8.262353  34.110588   85.956471  158.438824
#                     Aug    7.094286  26.841429   74.917143  156.792857
#                     Dec    7.126154  32.252308  111.561538  235.387692
#                     Feb    6.770909  36.250909   83.874545  175.258182
#                     Jan    8.252747  33.768132   82.348352  144.829670

# %%
df_grouped.reset_index(inplace=True)

# %%
df_grouped[df_grouped['state']=='Andhra Pradesh']
# Out:
#              state  year month        so2        no2        rspm         spm
# 0   Andhra Pradesh  2004   Apr   8.262353  34.110588   85.956471  158.438824
# 1   Andhra Pradesh  2004   Aug   7.094286  26.841429   74.917143  156.792857
# 2   Andhra Pradesh  2004   Dec   7.126154  32.252308  111.561538  235.387692
# 3   Andhra Pradesh  2004   Feb   6.770909  36.250909   83.874545  175.258182
# 4   Andhra Pradesh  2004   Jan   8.252747  33.768132   82.348352  144.829670
# 5   Andhra Pradesh  2004   Jul   8.001786  29.991071   81.638393  148.487500
# 6   Andhra Pradesh  2004   Jun   6.414706  27.997059   79.647059  174.745588
# 7   Andhra Pradesh  2004   Mar   6.718182  35.818182   83.454545  178.859091
# 8   Andhra Pradesh  2004   May   6.242857  31.007143   79.519643  166.853571
# 9   Andhra Pradesh  2004   Nov   6.531429  30.275714   89.914286  195.834286
# 10  Andhra Pradesh  2004   Oct   8.356250  30.742857   88.429464  165.899107
# ...

# %%
df_refined.head()
# Out:
#                state   so2    no2   rspm    spm month  year
# 1036  Andhra Pradesh  12.9   55.8  143.7  370.7   Feb  2004
# 1037  Andhra Pradesh  10.4   48.9  124.7  285.7   May  2004
# 1038  Andhra Pradesh   7.6   50.1   88.0  221.3   Sep  2004
# 1039  Andhra Pradesh   7.3   48.5   82.7  186.7   Dec  2004
# 1040  Andhra Pradesh   6.8  110.3  122.3  270.7   Jan  2004

# %%
df_new=df_refined.drop(columns=['state'])

# %%
df_new.head()
# Out:
#        so2    no2   rspm    spm month  year
# 1036  12.9   55.8  143.7  370.7   Feb  2004
# 1037  10.4   48.9  124.7  285.7   May  2004
# 1038   7.6   50.1   88.0  221.3   Sep  2004
# 1039   7.3   48.5   82.7  186.7   Dec  2004
# 1040   6.8  110.3  122.3  270.7   Jan  2004

# %%
df_grouped=df_new.groupby(['year','month']).mean()

# %%
mean_temp=pd.read_csv('mean_temp.csv')

# %%
mean_temp.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
# 2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  21.73  18.95   24.23    18.71    26.06    27.30    21.92
# 1  21.33  18.78   24.33    19.70    26.44    27.18    21.49
# 2  20.96  18.29   23.80    19.05    25.47    27.17    21.27
# 3  21.07  18.84   23.86    18.66    25.84    26.83    21.42
# 4  22.07  18.71   23.71    17.58    24.99    27.37    21.48

# %%
mean_temp.transpose()
# Out:
#              0        1        2        3        4        5        6    \
# YEAR     1901.00  1902.00  1903.00  1904.00  1905.00  1906.00  1907.00
# JAN        17.99    19.00    18.32    17.77    17.40    17.50    19.27
# FEB        19.43    20.39    19.79    19.39    17.79    19.14    19.42
# MAR        23.49    24.10    22.46    22.95    21.78    22.21    22.03
# APR        26.41    26.54    26.03    26.73    24.84    26.53    26.98
# MAY        28.28    28.68    27.93    27.83    28.32    29.06    27.52
# JUN        28.60    28.44    28.41    27.85    28.69    28.02    27.66
# JUL        27.49    27.29    28.04    26.84    27.67    27.46    27.28
# AUG        26.98    27.05    26.63    26.73    27.47    26.82    26.38
# SEP        26.26    25.95    26.34    25.84    26.29    26.23    26.26
# OCT        25.08    24.37    24.57    24.36    26.16    24.75    24.72
# NOV        21.73    21.33    20.96    21.07    22.07    21.93    22.11
# ...

# %%
mean_temp_r=mean_temp.set_index('YEAR')
mean_temp_r.head()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
# 1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
#
#         NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# YEAR
# 1901  21.73  18.95   24.23    18.71    26.06    27.30    21.92
# 1902  21.33  18.78   24.33    19.70    26.44    27.18    21.49
# 1903  20.96  18.29   23.80    19.05    25.47    27.17    21.27
# 1904  21.07  18.84   23.86    18.66    25.84    26.83    21.42
# 1905  22.07  18.71   23.71    17.58    24.99    27.37    21.48

# %%
mean_temp_r.loc[1901,'JAN']
# Out:
# 17.99

# %%
df_grouped.head()
# Out:
#                  so2        no2       rspm         spm
# year month
# 2003 Apr    3.565789  13.315789  46.802632  123.605263
#      Aug    3.897436  14.089744  40.141026  106.576923
#      Dec    6.116279  26.883721  87.813953  215.372093
#      Feb    2.576471  10.505882  36.376471   87.941176
#      Jan    2.929293  11.383838  46.636364  112.535354

# %%
df_grouped.reset_index(inplace=True)

# %%
new_cols=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Annual','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec']
mean_temp_r.columns=new_cols

# %%
y=df_grouped['year']
m=df_grouped['month']

# %%
temp=[]

# %%
for year,month in zip(y,m):
    t=mean_temp_r.loc[int(year),month]
    temp.append(t)

# %%
temp
# Out:
# [27.29,
#  27.25,
#  19.59,
#  21.03,
#  18.6,
#  27.53,
#  29.01,
#  23.62,
#  28.64,
#  22.17,
#  24.92,
#  26.75,
#  27.38,
#  27.16,
#  19.93,
#  21.03,
#  18.83,
#  27.44,
#  27.94,
#  26.19,
#  28.12,
#  22.43,
#  24.34,
#  26.8,
#  26.62,
#  27.41,
#  19.23,
#  20.51,
#  19.07,
#  27.34,
#  28.99,
#  24.14,
#  28.22,
#  21.73,
#  24.84,
#  26.82,
#  26.83,
#  27.15,
#  19.99,
#  23.02,
#  19.96,
#  27.92,
#  28.13,
#  23.91,
#  28.82,
#  22.59,
#  25.41,
#  26.42,
#  27.72,
#  27.37,
#  19.65,
#  20.97,
#  19.24,
#  27.66,
#  28.31,
#  23.52,
#  28.84,
#  22.4,
#  24.92,
#  26.61,
#  26.54,
#  27.0,
#  20.62,
#  19.83,
#  18.49,
#  27.5,
#  28.1,
#  24.43,
#  28.42,
#  22.51,
#  25.47,
#  26.44,
#  27.35,
#  27.85,
#  20.22,
#  21.66,
#  19.79,
#  27.83,
#  28.77,
#  24.55,
#  28.71,
#  22.31,
#  25.2,
#  27.11,
#  28.4,
#  27.33,
#  19.22,
#  21.23,
#  19.15,
#  27.55,
#  28.51,
#  26.53,
#  29.19,
#  22.98,
#  25.58,
#  26.6,
#  26.1,
#  27.2,
#  19.84,
#  20.79,
#  18.32,
# ...

# %%
len(temp)
# Out:
# 120

# %%
df_grouped.shape
# Out:
# (120, 6)

# %% [markdown]
# AWESOMME

# %%
df_grouped['Temperature']=temp

# %%
df_grouped.head()
# Out:
#    year month       so2        no2       rspm         spm  Temperature
# 0  2003   Apr  3.565789  13.315789  46.802632  123.605263        27.29
# 1  2003   Aug  3.897436  14.089744  40.141026  106.576923        27.25
# 2  2003   Dec  6.116279  26.883721  87.813953  215.372093        19.59
# 3  2003   Feb  2.576471  10.505882  36.376471   87.941176        21.03
# 4  2003   Jan  2.929293  11.383838  46.636364  112.535354        18.60

# %%
df_grouped.shape
# Out:
# (120, 7)

# %%
df_grouped
# Out:
#      year month        so2        no2        rspm         spm  Temperature
# 0    2003   Apr   3.565789  13.315789   46.802632  123.605263        27.29
# 1    2003   Aug   3.897436  14.089744   40.141026  106.576923        27.25
# 2    2003   Dec   6.116279  26.883721   87.813953  215.372093        19.59
# 3    2003   Feb   2.576471  10.505882   36.376471   87.941176        21.03
# 4    2003   Jan   2.929293  11.383838   46.636364  112.535354        18.60
# 5    2003   Jul   2.797980  11.373737   33.323232   79.878788        27.53
# 6    2003   Jun   2.902439  10.939024   34.841463   94.341463        29.01
# 7    2003   Mar   3.448276  12.505747   44.827586  102.275862        23.62
# 8    2003   May   2.886364  11.090909   43.340909  119.954545        28.64
# 9    2003   Nov   7.166667  27.500000   88.595238  231.952381        22.17
# 10   2003   Oct   6.881356  26.440678   93.661017  255.694915        24.92
# ...

# %%
last_rows=pd.read_csv('Not_final.csv')

# %%
last_rows=last_rows.tail(24)

# %%
last_rows.shape
# Out:
# (24, 4)

# %%
last_rows.reset_index(inplace=True)

# %%
n_years=[]
for i in range(12):
    n_years.append(2014)

# %%
for i in range(12):
    n_years.append(2015)

# %%
len(n_years)
# Out:
# 24

# %%
n_years
# Out:
# [2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015]

# %%
monthss=new_cols[:12]

# %%
monthss=monthss*2

# %%
monthss
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec',
#  'Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
last_rows['year']=n_years
last_rows['month']=monthss

# %%
last_rows.drop(columns=['index','Unnamed: 3'],inplace=True)

# %%
last_rows
# Out:
#           SO2        NO2        RSPM  year month
# 0   10.121903  25.941380  115.360513  2014   Jan
# 1    9.134411  24.684720  107.334593  2014   Feb
# 2    9.334490  24.546242  107.305429  2014   Mar
# 3    9.521922  24.478212  104.847034  2014   Apr
# 4    9.416317  24.428386  102.454001  2014   May
# 5    8.790528  23.214360   98.614615  2014   Jun
# 6    8.997589  22.726727   88.613478  2014   Jul
# 7    8.215045  22.298791   89.099284  2014   Aug
# 8    8.435835  23.123789   91.256792  2014   Sep
# 9    9.271315  24.616527  105.314427  2014   Oct
# 10   8.646173  26.043664  112.108593  2014   Nov
# 11   9.099608  26.054969  115.930029  2014   Dec
# 12   9.252626  25.885679  109.892597  2015   Jan
# 13   9.199601  25.053862  110.280090  2015   Feb
# 14   8.977774  23.823087  104.123853  2015   Mar
# 15   8.454571  23.285950  106.500759  2015   Apr
# 16   8.455007  23.021248  105.380401  2015   May
# 17   7.929885  21.326282   89.672317  2015   Jun
# ...

# %%
cols=['year','month','SO2','NO2','RSPM']

# %%
last_rows=last_rows[cols]

# %%
last_rows
# Out:
#     year month        SO2        NO2        RSPM
# 0   2014   Jan  10.121903  25.941380  115.360513
# 1   2014   Feb   9.134411  24.684720  107.334593
# 2   2014   Mar   9.334490  24.546242  107.305429
# 3   2014   Apr   9.521922  24.478212  104.847034
# 4   2014   May   9.416317  24.428386  102.454001
# 5   2014   Jun   8.790528  23.214360   98.614615
# 6   2014   Jul   8.997589  22.726727   88.613478
# 7   2014   Aug   8.215045  22.298791   89.099284
# 8   2014   Sep   8.435835  23.123789   91.256792
# 9   2014   Oct   9.271315  24.616527  105.314427
# 10  2014   Nov   8.646173  26.043664  112.108593
# 11  2014   Dec   9.099608  26.054969  115.930029
# 12  2015   Jan   9.252626  25.885679  109.892597
# 13  2015   Feb   9.199601  25.053862  110.280090
# 14  2015   Mar   8.977774  23.823087  104.123853
# 15  2015   Apr   8.454571  23.285950  106.500759
# 16  2015   May   8.455007  23.021248  105.380401
# 17  2015   Jun   7.929885  21.326282   89.672317
# ...

# %%
df_final=df_grouped.drop(columns=['spm'])

# %%
df_final.head()
# Out:
#    year month       so2        no2       rspm  Temperature
# 0  2003   Apr  3.565789  13.315789  46.802632        27.29
# 1  2003   Aug  3.897436  14.089744  40.141026        27.25
# 2  2003   Dec  6.116279  26.883721  87.813953        19.59
# 3  2003   Feb  2.576471  10.505882  36.376471        21.03
# 4  2003   Jan  2.929293  11.383838  46.636364        18.60

# %%
t_last2=pd.read_csv('mean_temp.csv')

# %%
t_last2=t_last2.tail(4)

# %%
t_last2
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42  26.61
# 114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64  27.04
# 115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17  27.72
# 116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12  28.11
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 113  25.38  22.53  19.50   24.73    19.58    26.24    27.88    22.47
# 114  25.82  22.95  20.21   24.91    20.12    26.29    27.73    22.99
# 115  26.81  23.90  21.89   26.45    22.25    28.86    28.44    24.20
# 116  27.24  23.92  21.47   26.29    21.84    28.41    28.50    24.21

# %%
t_last2=t_last2.iloc[:2,:]

# %%
t_last2.reset_index(inplace=True)

# %%
new_cols=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Annual','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec']

# %%
t_last2.set_index('YEAR',inplace=True)

# %%
t_last2.drop(columns=['index'],inplace=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
t_last2
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42  26.61  25.38
# 2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64  27.04  25.82
#
#         NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# YEAR
# 2014  22.53  19.50   24.73    19.58    26.24    27.88    22.47
# 2015  22.95  20.21   24.91    20.12    26.29    27.73    22.99

# %%
t_last2.shape
# Out:
# (2, 17)

# %%
len(new_cols)
# Out:
# 17

# %%
t_last2.columns=new_cols

# %%
t_last2
# Out:
#         Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# YEAR
# 2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42  26.61  25.38
# 2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64  27.04  25.82
#
#         Nov    Dec  Annual  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# YEAR
# 2014  22.53  19.50   24.73    19.58    26.24    27.88    22.47
# 2015  22.95  20.21   24.91    20.12    26.29    27.73    22.99

# %%
t_last2.reset_index(inplace=True)

# %%
t_last2.rename(columns={'YEAR':'year'})
# Out:
#    year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42  26.61  25.38
# 1  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64  27.04  25.82
#
#      Nov    Dec  Annual  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 0  22.53  19.50   24.73    19.58    26.24    27.88    22.47
# 1  22.95  20.21   24.91    20.12    26.29    27.73    22.99

# %%
t_last2=t_last2.transpose()

# %%
temp_2014=t_last2.iloc[1:,0]
temp_2015=t_last2.iloc[1:,1]

# %%
temp_2014[:12]
# Out:
# Jan    18.81
# Feb    20.35
# Mar    23.34
# Apr    26.91
# May    28.45
# Jun    29.42
# Jul    28.07
# Aug    27.42
# Sep    26.61
# Oct    25.38
# Nov    22.53
# Dec    19.50
# Name: 0, dtype: float64

# %%
last_two_temps=list(temp_2014[:12])+list(temp_2015[:12])

# %%
last_two_temps
# Out:
# [18.81,
#  20.35,
#  23.34,
#  26.91,
#  28.45,
#  29.42,
#  28.07,
#  27.42,
#  26.61,
#  25.38,
#  22.53,
#  19.5,
#  19.02,
#  21.23,
#  23.52,
#  26.52,
#  28.82,
#  28.15,
#  28.03,
#  27.64,
#  27.04,
#  25.82,
#  22.95,
#  20.21]

# %%
last_rows['Temperature']=last_two_temps
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
last_rows
# Out:
#     year month        SO2        NO2        RSPM  Temperature
# 0   2014   Jan  10.121903  25.941380  115.360513        18.81
# 1   2014   Feb   9.134411  24.684720  107.334593        20.35
# 2   2014   Mar   9.334490  24.546242  107.305429        23.34
# 3   2014   Apr   9.521922  24.478212  104.847034        26.91
# 4   2014   May   9.416317  24.428386  102.454001        28.45
# 5   2014   Jun   8.790528  23.214360   98.614615        29.42
# 6   2014   Jul   8.997589  22.726727   88.613478        28.07
# 7   2014   Aug   8.215045  22.298791   89.099284        27.42
# 8   2014   Sep   8.435835  23.123789   91.256792        26.61
# 9   2014   Oct   9.271315  24.616527  105.314427        25.38
# 10  2014   Nov   8.646173  26.043664  112.108593        22.53
# 11  2014   Dec   9.099608  26.054969  115.930029        19.50
# 12  2015   Jan   9.252626  25.885679  109.892597        19.02
# 13  2015   Feb   9.199601  25.053862  110.280090        21.23
# ...

# %%
df_final.head()
# Out:
#    year month       so2        no2       rspm  Temperature
# 0  2003   Apr  3.565789  13.315789  46.802632        27.29
# 1  2003   Aug  3.897436  14.089744  40.141026        27.25
# 2  2003   Dec  6.116279  26.883721  87.813953        19.59
# 3  2003   Feb  2.576471  10.505882  36.376471        21.03
# 4  2003   Jan  2.929293  11.383838  46.636364        18.60

# %%
last_rows.head()
# Out:
#    year month        SO2        NO2        RSPM  Temperature
# 0  2014   Jan  10.121903  25.941380  115.360513        18.81
# 1  2014   Feb   9.134411  24.684720  107.334593        20.35
# 2  2014   Mar   9.334490  24.546242  107.305429        23.34
# 3  2014   Apr   9.521922  24.478212  104.847034        26.91
# 4  2014   May   9.416317  24.428386  102.454001        28.45

# %%
last_rows.columns=df_final.columns

# %%
df_final=df_final.append(last_rows)

# %%
df_final.tail()
# Out:
#     year month       so2        no2        rspm  Temperature
# 19  2015   Aug  7.664517  20.602625   76.676577        27.64
# 20  2015   Sep  7.625425  21.791413   86.978024        27.04
# 21  2015   Oct  8.370018  24.088756  100.549949        25.82
# 22  2015   Nov  8.897189  26.255744  116.595667        22.95
# 23  2015   Dec  9.030675  27.205913  121.507433        20.21

# %%
df_final.shape
# Out:
# (144, 6)

# %%
df_final.reset_index(inplace=True)

# %%
df_final.drop(columns=['index'],inplace=True)

# %%
df_final
# Out:
#      year month        so2        no2        rspm  Temperature
# 0    2003   Apr   3.565789  13.315789   46.802632        27.29
# 1    2003   Aug   3.897436  14.089744   40.141026        27.25
# 2    2003   Dec   6.116279  26.883721   87.813953        19.59
# 3    2003   Feb   2.576471  10.505882   36.376471        21.03
# 4    2003   Jan   2.929293  11.383838   46.636364        18.60
# 5    2003   Jul   2.797980  11.373737   33.323232        27.53
# 6    2003   Jun   2.902439  10.939024   34.841463        29.01
# 7    2003   Mar   3.448276  12.505747   44.827586        23.62
# 8    2003   May   2.886364  11.090909   43.340909        28.64
# 9    2003   Nov   7.166667  27.500000   88.595238        22.17
# 10   2003   Oct   6.881356  26.440678   93.661017        24.92
# 11   2003   Sep   3.535211  13.788732   39.788732        26.75
# 12   2004   Apr  12.165050  27.545932  117.378512        27.38
# 13   2004   Aug  11.399592  25.032853   98.787147        27.16
# ...

# %%
df_final.to_csv('df_final.csv')

# %%
date=[1 for i in range(0,144)]

# %%
df_final['date']=date

# %%
df_final.head()
# Out:
#    year month       so2        no2       rspm  Temperature  date
# 0  2003   Apr  3.565789  13.315789  46.802632        27.29     1
# 1  2003   Aug  3.897436  14.089744  40.141026        27.25     1
# 2  2003   Dec  6.116279  26.883721  87.813953        19.59     1
# 3  2003   Feb  2.576471  10.505882  36.376471        21.03     1
# 4  2003   Jan  2.929293  11.383838  46.636364        18.60     1

# %%
df_final.drop(columns='dates',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-372-a5d4948a92ac> in <module>()
# ----> 1 df_final.drop(columns='dates',inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
df_final.dtypes
# Out:
# year            object
# month           object
# so2            float64
# no2            float64
# rspm           float64
# Temperature    float64
# date             int64
# dtype: object

# %%
dates=[]
for y,m,d in zip(df_final['year'],df_final['month'],df_final['date']):
    date="{}-{}-{}".format(y,m,d)
    date=datetime.datetime.strptime(date,"%Y-%b-%d")
    dates.append(date)

# %%
dates
# Out:
# [datetime.datetime(2003, 4, 1, 0, 0),
#  datetime.datetime(2003, 8, 1, 0, 0),
#  datetime.datetime(2003, 12, 1, 0, 0),
#  datetime.datetime(2003, 2, 1, 0, 0),
#  datetime.datetime(2003, 1, 1, 0, 0),
#  datetime.datetime(2003, 7, 1, 0, 0),
#  datetime.datetime(2003, 6, 1, 0, 0),
#  datetime.datetime(2003, 3, 1, 0, 0),
#  datetime.datetime(2003, 5, 1, 0, 0),
#  datetime.datetime(2003, 11, 1, 0, 0),
#  datetime.datetime(2003, 10, 1, 0, 0),
#  datetime.datetime(2003, 9, 1, 0, 0),
#  datetime.datetime(2004, 4, 1, 0, 0),
#  datetime.datetime(2004, 8, 1, 0, 0),
#  datetime.datetime(2004, 12, 1, 0, 0),
#  datetime.datetime(2004, 2, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 7, 1, 0, 0),
#  datetime.datetime(2004, 6, 1, 0, 0),
#  datetime.datetime(2004, 3, 1, 0, 0),
#  datetime.datetime(2004, 5, 1, 0, 0),
#  datetime.datetime(2004, 11, 1, 0, 0),
#  datetime.datetime(2004, 10, 1, 0, 0),
#  datetime.datetime(2004, 9, 1, 0, 0),
# ...

# %%
df_final['dates']=dates

# %%
df_final.head()
# Out:
#    year month       so2        no2       rspm  Temperature  date      dates
# 0  2003   Apr  3.565789  13.315789  46.802632        27.29     1 2003-04-01
# 1  2003   Aug  3.897436  14.089744  40.141026        27.25     1 2003-08-01
# 2  2003   Dec  6.116279  26.883721  87.813953        19.59     1 2003-12-01
# 3  2003   Feb  2.576471  10.505882  36.376471        21.03     1 2003-02-01
# 4  2003   Jan  2.929293  11.383838  46.636364        18.60     1 2003-01-01

# %%
df_final.drop(columns=['year','month','date'],inplace=True)

# %%
df_final.head()
# Out:
#         so2        no2       rspm  Temperature      dates
# 0  3.565789  13.315789  46.802632        27.29 2003-04-01
# 1  3.897436  14.089744  40.141026        27.25 2003-08-01
# 2  6.116279  26.883721  87.813953        19.59 2003-12-01
# 3  2.576471  10.505882  36.376471        21.03 2003-02-01
# 4  2.929293  11.383838  46.636364        18.60 2003-01-01

# %%
df_final.set_index(['dates'],inplace=True)

# %%
df_final.head()
# Out:
#                  so2        no2       rspm  Temperature
# dates
# 2003-04-01  3.565789  13.315789  46.802632        27.29
# 2003-08-01  3.897436  14.089744  40.141026        27.25
# 2003-12-01  6.116279  26.883721  87.813953        19.59
# 2003-02-01  2.576471  10.505882  36.376471        21.03
# 2003-01-01  2.929293  11.383838  46.636364        18.60

# %%
df_final.dtypes
# Out:
# so2            float64
# no2            float64
# rspm           float64
# Temperature    float64
# dtype: object

# %%
df_final.to_csv('updated_final.csv')

# %% [markdown]
# # DATASET PREP DONE...NOW TIMESERIES TIME

# %%
df_final.index
# Out:
# DatetimeIndex(['2003-04-01', '2003-08-01', '2003-12-01', '2003-02-01',
#                '2003-01-01', '2003-07-01', '2003-06-01', '2003-03-01',
#                '2003-05-01', '2003-11-01',
#                ...
#                '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01',
#                '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01',
#                '2015-11-01', '2015-12-01'],
#               dtype='datetime64[ns]', name='dates', length=144, freq=None)

# %%
df_final.to_csv('update_final.csv')

# %%
df_final.head()
# Out:
#                  so2        no2       rspm  Temperature
# dates
# 2003-04-01  3.565789  13.315789  46.802632        27.29
# 2003-08-01  3.897436  14.089744  40.141026        27.25
# 2003-12-01  6.116279  26.883721  87.813953        19.59
# 2003-02-01  2.576471  10.505882  36.376471        21.03
# 2003-01-01  2.929293  11.383838  46.636364        18.60

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# %%
train = df_final[:int(0.8*(len(df_final)))]
valid = df_final[int(0.8*(len(df_final))):]

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
model = VAR(endog=train)
model_fit = model.fit()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
prediction = model_fit.forecast(model_fit.y, steps=len(valid))

# %%
cols = df_final.columns

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
pred = pd.DataFrame(index=range(0,len(prediction)),columns=[cols])
for j in range(0,4):
    for i in range(0, len(prediction)):
       pred.iloc[i][j] = prediction[i][j]

#check rmse
for i in cols:
    print('rmse value for', i, 'is : ', sqrt(mean_squared_error(pred[i], valid[i])))
# Out:
# rmse value for so2 is :  2.342770420022188
# rmse value for no2 is :  4.335364618623296
# rmse value for rspm is :  15.838980910371342
# rmse value for Temperature is :  3.2703811641538754

# %%
df_final.tail()
# Out:
#                  so2        no2        rspm  Temperature
# dates
# 2015-08-01  7.664517  20.602625   76.676577        27.64
# 2015-09-01  7.625425  21.791413   86.978024        27.04
# 2015-10-01  8.370018  24.088756  100.549949        25.82
# 2015-11-01  8.897189  26.255744  116.595667        22.95
# 2015-12-01  9.030675  27.205913  121.507433        20.21

# %%
model = VAR(endog=df_final)
model_fit = model.fit()
yhat = model_fit.forecast(model_fit.y, steps=1)
print(yhat)
# Out:
# [[ 8.48991706 24.66860363 99.75105189 23.96093257]]
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model = VAR(endog=df_final)
model_fit = model.fit()
yhat = model_fit.forecast(model_fit.y, steps=1)
print(yhat)
# Out:
# [[ 8.48991706 24.66860363 99.75105189 23.96093257]]
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
a=datetime.datetime.strptime("2016-01-01","%Y-%m-%d")

# %%
li=[]

# %%
li.append(a)

# %%
a=yhat.tolist()[0]

# %%
a
# Out:
# [8.489917055422245, 24.668603627354354, 99.75105188777096, 23.9609325661592]

# %%
li
# Out:
# [datetime.datetime(2016, 1, 1, 0, 0)]

# %%
li.extend(a)

# %%
li
# Out:
# [datetime.datetime(2016, 1, 1, 0, 0),
#  8.489917055422245,
#  24.668603627354354,
#  99.75105188777096,
#  23.9609325661592]

# %%
df_final.reset_index(inplace=True)

# %%
a=datetime.datetime.strptime("2016-01-01","%Y-%m-%d")
print(a)
# Out:
# 2016-01-01 00:00:00

# %%
df_final.head()
# Out:
#        dates       so2        no2       rspm  Temperature
# 0 2003-04-01  3.565789  13.315789  46.802632        27.29
# 1 2003-08-01  3.897436  14.089744  40.141026        27.25
# 2 2003-12-01  6.116279  26.883721  87.813953        19.59
# 3 2003-02-01  2.576471  10.505882  36.376471        21.03
# 4 2003-01-01  2.929293  11.383838  46.636364        18.60

# %%
df_final=df_final.append({'dates' : a , 'so2' : li[1],'no2':li[2],'rspm':li[3],'Temperature':li[4]} , ignore_index=True)

# %%
df_final.dtypes
# Out:
# dates          datetime64[ns]
# so2                   float64
# no2                   float64
# rspm                  float64
# Temperature           float64
# dtype: object

# %%
df_final.tail()
# Out:
#          dates       so2        no2        rspm  Temperature
# 140 2015-09-01  7.625425  21.791413   86.978024    27.040000
# 141 2015-10-01  8.370018  24.088756  100.549949    25.820000
# 142 2015-11-01  8.897189  26.255744  116.595667    22.950000
# 143 2015-12-01  9.030675  27.205913  121.507433    20.210000
# 144 2016-01-01  8.489917  24.668604   99.751052    23.960933

# %%
df_final.set_index(['dates'],inplace=True)

# %%
df_final.tail()
# Out:
#                  so2        no2        rspm  Temperature
# dates
# 2015-09-01  7.625425  21.791413   86.978024    27.040000
# 2015-10-01  8.370018  24.088756  100.549949    25.820000
# 2015-11-01  8.897189  26.255744  116.595667    22.950000
# 2015-12-01  9.030675  27.205913  121.507433    20.210000
# 2016-01-01  8.489917  24.668604   99.751052    23.960933

# %%
for i in range(2,13):
    model = VAR(endog=df_final)
    model_fit = model.fit()
    yhat = model_fit.forecast(model_fit.y, steps=1)
    a=datetime.datetime.strptime("2016-{}-01".format(i),"%Y-%m-%d")
    new_r=[]
    new_r.append(a)
    new_r.extend(yhat.tolist()[0])
    df_final.reset_index(inplace=True)
    df_final=df_final.append({'dates' : a , 'so2' : new_r[1],'no2':new_r[2],'rspm':new_r[3],'Temperature':new_r[4]} , ignore_index=True)
    df_final.set_index(['dates'],inplace=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
df_final.tail()
# Out:
#                  so2        no2       rspm  Temperature
# dates
# 2016-08-01  9.288877  24.574445  97.737423    24.855437
# 2016-09-01  9.385141  24.667920  98.160922    24.847624
# 2016-10-01  9.472234  24.757451  98.554174    24.841002
# 2016-11-01  9.550857  24.842229  98.917319    24.835395
# 2016-12-01  9.621694  24.921770  99.251050    24.830645

# %%
df_final
# Out:
#                   so2        no2        rspm  Temperature
# dates
# 2003-04-01   3.565789  13.315789   46.802632    27.290000
# 2003-08-01   3.897436  14.089744   40.141026    27.250000
# 2003-12-01   6.116279  26.883721   87.813953    19.590000
# 2003-02-01   2.576471  10.505882   36.376471    21.030000
# 2003-01-01   2.929293  11.383838   46.636364    18.600000
# 2003-07-01   2.797980  11.373737   33.323232    27.530000
# 2003-06-01   2.902439  10.939024   34.841463    29.010000
# 2003-03-01   3.448276  12.505747   44.827586    23.620000
# 2003-05-01   2.886364  11.090909   43.340909    28.640000
# 2003-11-01   7.166667  27.500000   88.595238    22.170000
# 2003-10-01   6.881356  26.440678   93.661017    24.920000
# 2003-09-01   3.535211  13.788732   39.788732    26.750000
# 2004-04-01  12.165050  27.545932  117.378512    27.380000
# 2004-08-01  11.399592  25.032853   98.787147    27.160000
# 2004-12-01  13.116870  29.142550  140.315395    19.930000
# ...

# %%
for i in range(1,13):
    model = VAR(endog=df_final)
    model_fit = model.fit()
    yhat = model_fit.forecast(model_fit.y, steps=1)
    a=datetime.datetime.strptime("2017-{}-01".format(i),"%Y-%m-%d")
    new_r=[]
    new_r.append(a)
    new_r.extend(yhat.tolist()[0])
    df_final.reset_index(inplace=True)
    df_final=df_final.append({'dates' : a , 'so2' : new_r[1],'no2':new_r[2],'rspm':new_r[3],'Temperature':new_r[4]} , ignore_index=True)
    df_final.set_index(['dates'],inplace=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
df_final
# Out:
#                   so2        no2        rspm  Temperature
# dates
# 2003-04-01   3.565789  13.315789   46.802632    27.290000
# 2003-08-01   3.897436  14.089744   40.141026    27.250000
# 2003-12-01   6.116279  26.883721   87.813953    19.590000
# 2003-02-01   2.576471  10.505882   36.376471    21.030000
# 2003-01-01   2.929293  11.383838   46.636364    18.600000
# 2003-07-01   2.797980  11.373737   33.323232    27.530000
# 2003-06-01   2.902439  10.939024   34.841463    29.010000
# 2003-03-01   3.448276  12.505747   44.827586    23.620000
# 2003-05-01   2.886364  11.090909   43.340909    28.640000
# 2003-11-01   7.166667  27.500000   88.595238    22.170000
# 2003-10-01   6.881356  26.440678   93.661017    24.920000
# 2003-09-01   3.535211  13.788732   39.788732    26.750000
# 2004-04-01  12.165050  27.545932  117.378512    27.380000
# 2004-08-01  11.399592  25.032853   98.787147    27.160000
# 2004-12-01  13.116870  29.142550  140.315395    19.930000
# ...

# %%
df_final.to_csv('upd_predicted.csv')
